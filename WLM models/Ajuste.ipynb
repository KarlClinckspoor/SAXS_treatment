# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-the-necessary-components" data-toc-modified-id="Importing-the-necessary-components-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing the necessary components</a></span></li><li><span><a href="#Plotting-the-fit-interactively" data-toc-modified-id="Plotting-the-fit-interactively-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plotting the fit interactively</a></span></li></ul></div>

# %% [markdown]
# # Importing the necessary components
#
# Loading "nbagg" is necessary to make the plot interactively.

# %%
import matplotlib as mpl
mpl.use('nbagg')
from interactive_fit import plot_fit

# %% [markdown]
# # Plotting the fit interactively

# %%
plot_fit()
# Out:
# <img src="data:image/png;base64,..." width="600">
